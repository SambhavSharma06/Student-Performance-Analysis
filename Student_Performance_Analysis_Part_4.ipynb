# %% [markdown]
# **Day-15**

# %% [markdown]
# **Look back at your findings**

# %% [markdown]
# *Open them and look at both.*

# %% [markdown]
# **Answer these three questions**

# %% [markdown]
# *Do higher-grade students study more?* YES

# %% [markdown]
# *Does attendance change a lot between grades?* NO

# %% [markdown]
# *Which one matters more according to this data?* Study Hours

# %% [markdown]
# **Write your final project conclusion**

# %% [markdown]
# *In this project, I analyzed how study habits and attendance affect student performance. The analysis shows that students with higher grades have significantly higher study hours, while attendance remains fairly similar across all grades. This suggests that self-study plays a stronger role in improving marks than simply attending classes. Therefore, encouraging students to spend more time studying independently could lead to better academic results.*
