# %% [markdown]
# **Day-13**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/student_performance.csv')
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %% [markdown]
# **Re-Run Yesterday's analysis**

# %%
df.groupby('grade')['weekly_self_study_hours'].mean()
# Out:
# grade
# A    19.375738
# B    12.115533
# C     7.691161
# D     3.764143
# F     1.524662
# Name: weekly_self_study_hours, dtype: float64

# %% [markdown]
# **Create ONE simple bar chart**

# %%
df.groupby('grade')['weekly_self_study_hours'].mean().plot(kind = 'bar',title = 'Average Study Hours By Grade')
# Out:
# <Axes: title={'center': 'Average Study Hours By Grade'}, xlabel='grade'>

# %% [markdown]
# **Which grade has the tallest bar**

# %% [markdown]
# *A Bar*

# %% [markdown]
# **Which grade has the smallest bar**

# %% [markdown]
# *F* *bar*

# %% [markdown]
# **Does the chart match yesterday's numeric result**

# %% [markdown]
# *Yes it does*

# %% [markdown]
# **Write ONE clear Explanation**

# %% [markdown]
# *The bar chart shows that students with higher grades have higher study hours. THis visually supports the numerical analysis done earlier.*
