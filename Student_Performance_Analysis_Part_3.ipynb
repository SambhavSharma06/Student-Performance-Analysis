# %% [markdown]
# **Day-14**

# %% [markdown]
# **Use the SAME project data**

# %%
import pandas as pd
df = pd.read_csv('/content/student_performance.csv')
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %% [markdown]
# **Do the attendance analysis**

# %%
df.groupby('grade')['attendance_percentage'].mean()
# Out:
# grade
# A    84.710114
# B    84.696178
# C    84.726340
# D    84.723243
# F    84.973662
# Name: attendance_percentage, dtype: float64

# %% [markdown]
# **Create ONE simple chart**

# %%
df.groupby('grade')['attendance_percentage'].mean().plot(kind='bar',title='Average Attendance by Grade')
# Out:
# <Axes: title={'center': 'Average Attendance by Grade'}, xlabel='grade'>

# %% [markdown]
# **Does attendance really separate good and bad students?**

# %% [markdown]
# *No,because as you can see all the students have over all same attendance but a big differance in GRADES*

# %% [markdown]
# **Write ONE honest observation**

# %% [markdown]
# *ATTENDANCE has a very weak realtionship with GRADES in this DATAFRAME*
